# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("\Users\JUHI\AnacondaProjects\Visualize It!\Train_Schedule.csv")
datalat=pd.read_csv("\Users\JUHI\AnacondaProjects\Visualize It!\Dataset Later\Coordinates_for_railway_stations_cleaned.csv")


group_source = df.groupby('source Station Name').count()
group_source=group_source.sort_values('Train No.',ascending=False)
group_source=group_source[:15]
# Out:
#                      Train No.  train Name  islno  station Code  Station Name  \
# source Station Name
# ABOHAR                      60          60     60            60            60
# ADILABAD                    63          63     63            63            63
# ADRSH NGR DELHI             24          24     24            24            24
# AGRA CANTT                  86          86     86            86            86
# AGRA FORT                   95          95     95            95            95
# AHMEDABAD JN              1297        1297   1297          1297          1297
# AHMEDABAD MG                 9           9      9             9             9
# AISHBAGH                    17          17     17            17            17
# AJMER JN                   695         695    695           695           695
# AJNI                        27          27     27            27            27
# AKOLA JN                    91          91     91            91            91
# ...

# %% [markdown]
# group_source['Train No.'].plot(kind='bar')
# plt.figure(figsize=(100,1000))
# plt.show()

# %%
group_source['Train No.'].plot(kind='bar')
plt.figure(figsize=(100,1000))
plt.show()

# %%
group_source = df.groupby('source Station Name').count()
group_source=group_source.sort_values('Train No.',ascending=False)
group_source = group_source[:15]
group_source['Train No.'].plot(kind='bar')
plt.figure(figsize=(10,10))
plt.show()

# %%
group_source = df.groupby('source Station Name').count()
group_source=group_source.sort_values('Train No.',ascending=False)
group_source = group_source[:15]
group_source['Train No.'].plot(kind='bar')
plt.figure(figsize=(0,10))
plt.show()

# %%
group_source.plot.area()
plt.figure(figsize=(100,3),dpi=500)
plt.show()

# %%
group_source = df.groupby('source Station Name').count()
group_source=group_source.sort_values('Train No.',ascending=False)
group_source.plot.scatter(x='train Name', y='Distance', color='DarkGreen');
plt.figure(figsize=(100,3),dpi=500)
plt.show()

# %%
datalat.head()
# Out:
#               name        lat       long
# 0  BHUBANESWAR      20.296059  85.824540
# 1  BANGALORE CANT   12.993690  77.598142
# 2  DADAR            19.021324  72.842418
# 3  BHUSAVAL JN      21.046991  75.788382
# 4  CHALISGAON JN    20.463710  74.998863

# %%
group_source = df.groupby('source Station Name').count()
group_source=group_source.sort_values('Train No.',ascending=False)
group_source.plot.hexbin(x=datalat['lat'], y=datalat['long'], gridsize=250);
plt.figure()
plt.show()
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-87-6ece33115b07> in <module>()
#       1 group_source = df.groupby('source Station Name').count()
#       2 group_source=group_source.sort_values('Train No.',ascending=False)
# ----> 3 group_source.plot.hexbin(x=datalat['lat'], y=datalat['long'], gridsize=250);
#       4 plt.figure()
#       5 plt.show()
#
# C:\Users\JUHI\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwds)
#    2827         if gridsize is not None:
#    2828             kwds['gridsize'] = gridsize
# -> 2829         return self(kind='hexbin', x=x, y=y, C=C, **kwds)
#
# C:\Users\JUHI\Anaconda2\lib\site-packages\pandas\plotting\_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...
